# %% [markdown]
# # Predicting NBA Results Using Regular Season Statistics
# ##### Jason Fong, Kien Nguyen

# %% [markdown]
# ## Motivation
# - Knowing the outcome of the championship is something every sports fan wants to know.
# - You can make money in Vegas through betting
# - The goal of this project is to discover trends within successful NBA teams which may correlate to a championship.

# %% [markdown]
# ### Influence of the 3P Shot

# %%
# %matplotlib inline
exec(open("plots.py").read())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = pd.read_csv('./nba_data.csv')

# %%
plot_3pa()

# %%
plot_recent_3()

# %%
plot_champs()

# %%
#Importance of 3 pointers in the game has steadily increased
#Interesting to see a drop from 1997, the year that the 3p line
#distance went back up to its normal distance. The line was shortened
#to increase scoring
attempts = data.groupby('Year')['3P Attempts'].mean() / data.groupby('Year')['2P Attempts'].mean()
attempts.plot()

# %% [markdown]
# ## Talent Required

# %%
champs = data[data.Champion]
others = data[data.Champion == False]
plt.plot(champs['Year'], champs['Accolades'], 'y')
plt.plot(range(1960,2018), others.groupby('Year')['Accolades'].sum()/29)

# %%
plt.plot(champs['Year'], champs['APG'], 'y')
plt.plot(range(1960,2018), others.groupby('Year')['APG'].mean())

# %%
plt.plot(champs['Year'], champs['RPG'], 'y')
plt.plot(range(1960,2018), others.groupby('Year')['RPG'].mean())

# %%
plt.plot(champs[champs.Year > 1974]['Year'], champs[champs.Year > 1974]['TOVPG'], 'y')
plt.plot(range(1975,2018), others[others.Year > 1974].groupby('Year')['TOVPG'].mean())

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Team', 'Year', 'Wins', 'Champion', 'MVP',
#        'Scoring Leader', 'Rebound Leader', 'Assist Leader', 'WS Leader',
#        'DPOY', 'MIP', '6MOY', 'Coach of Year', 'All-Stars', 'All-Defensive',
#        'All-NBA', 'FG%', '3P Attempts', '3P%', '2P Attempts', '2P%', 'FT%',
#        'RPG', 'APG', 'STL', 'BLK', 'TOVPG', 'PPG', 'Accolades',
#        'Franchise ID'],
#       dtype='object')

# %%
plt.plot(champs['Year'], champs['FG%'], 'y')
plt.plot(range(1960,2018), others.groupby('Year')['FG%'].mean())

# %%
plt.plot(champs['Year'], champs['2P Attempts'], 'y')
plt.plot(range(1960,2018), others.groupby('Year')['2P Attempts'].mean())

# %%
exec(open("plots.py").read())
plot_2pa()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="24326323-e04a-4dff-9744-95fb0a20f4d7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("24326323-e04a-4dff-9744-95fb0a20f4d7", [{"type": "scatter", "marker": {"color": "yellow", "size": [26.0, 36.0, 23.0, 47.0, 51.0, 67.0, 73.0, 67.0]}, "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], "name": "Golden State Warriors", "y": [5407.0, 5298.0, 4092.0, 5208.0, 4968.0, 4920.0, 4567.0, 4577.0], "mode": "markers"}, {"type": "scatter", "marker": {"color": "red", "size": [61.0, 19.0, 21.0, 24.0, 33.0, 53.0, 57.0, 51.0]}, "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], "name": "Cleveland Cavaliers", "y": [4809.0, 5158.0, 4087.0, 5320.0, 5315.0, 4486.0, 4460.0, 4184.0], "mode": "markers"}], {"title": "Year vs. 2 Points Attempts", "updatemenus": [{"yanchor": "top", "y": 1, "x": -0.15}], "xaxis": {"title": "Year"}, "yaxis": {"title": "2 Points Attempts"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
plot_apg()
# Out:
# <div id="9384255b-305a-49b8-ade2-c02adb6b96bb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9384255b-305a-49b8-ade2-c02adb6b96bb", [{"name": "Data", "type": "scatter", "y": [94.4, 92.1, 94.8, 100.1, 99.3, 98.0, 96.6, 101.3, 98.4, 97.2, 103.5, 101.2, 97.0, 94.3, 84.8, 96.5, 96.2, 98.5, 101.4, 99.0, 99.5, 93.9, 100.8, 97.5, 98.9, 99.1, 105.0, 95.5, 92.0, 94.7, 88.9, 88.7, 97.5, 94.6, 92.1, 93.2, 100.7, 97.6, 91.9, 92.6, 95.6, 92.2, 91.0, 87.6, 96.2, 97.1, 100.5, 97.3, 97.2, 96.6, 91.7, 100.6, 101.7, 94.0, 95.4, 97.3, 92.5, 92.5, 96.2, 96.4, 100.5, 91.0, 92.8, 87.2, 91.6, 94.3, 93.9, 91.4, 96.8, 97.5, 94.0, 95.3, 89.5, 96.7, 105.2, 99.3, 96.0, 92.3, 92.2, 89.9, 104.6, 101.3, 96.6, 97.7, 95.7, 95.1, 97.7, 95.4, 96.8, 92.7, 98.5, 91.5, 95.9, 85.6, 91.4, 96.8, 93.9, 99.5, 94.1, 95.0, 90.9, 91.4, 95.8, 103.0, 98.1, 94.7, 93.8, 97.5, 84.2, 101.7, 100.4, 95.2, 95.5, 92.1, 102.4, 93.8, 90.3, 90.3, 92.0, 95.3, 88.0, 91.8, 94.0, 91.4, 90.1, 91.8, 98.0, 92.9, 85.4, 92.8, 89.7, 94.5, 91.5, 105.2, 96.7, 89.8, 97.2, 88.7, 98.2, 102.8, 90.7, 93.3, 97.1, 94.2, 94.8, 101.3, 99.1, 91.4, 99.7, 97.3, 93.3, 94.5, 93.0, 96.5, 97.2, 101.5, 100.5, 99.5, 94.3, 92.7, 98.9, 99.5, 96.8, 92.9, 93.0, 110.4, 103.7, 95.7, 98.7, 98.7, 96.2, 102.5, 95.1, 93.4, 88.4, 93.8, 99.4, 98.0, 101.1, 95.6, 96.8, 97.6, 93.9, 97.8, 97.8, 99.9, 101.7, 94.9, 96.9, 97.2, 100.3, 92.4, 102.6, 91.7, 88.8, 108.4, 97.2, 99.4, 98.9, 98.5, 95.6, 99.1, 92.2, 92.8, 90.1, 99.5, 97.6, 94.9, 97.5, 95.8, 96.0, 96.8, 98.8, 95.6, 99.7, 94.6, 104.3, 94.8, 96.9, 93.7, 101.5, 105.4, 94.1, 96.1, 99.1, 110.2, 103.3, 106.5, 95.6, 101.3, 100.0, 98.5, 97.0, 95.5, 101.6, 100.5, 100.2, 96.6, 95.8, 96.9, 97.5, 96.4, 104.0, 97.3, 97.0, 104.5, 98.8, 98.2, 97.1, 91.4, 106.2, 110.7, 95.4, 95.6, 97.5, 108.6, 110.1, 111.0, 102.5, 93.8, 100.9, 95.4, 96.7, 100.4, 100.7, 100.9, 97.4, 98.1, 99.0, 105.2, 100.3, 102.2, 94.2, 105.1, 99.3, 101.0, 98.1, 98.3, 93.6, 96.1, 104.3, 99.4, 103.6, 97.8, 97.0, 106.9, 109.4, 108.6, 95.1, 100.6, 97.0, 98.4, 101.7, 95.8, 93.9, 99.2, 104.1, 102.1, 97.7, 92.4, 102.1, 97.7, 97.5, 100.8, 94.0, 102.8, 101.7, 96.5, 95.3, 96.2, 106.5, 104.2, 98.1, 101.5, 98.2, 101.7, 110.2, 95.7, 108.8, 100.0, 102.0, 101.4, 102.4, 102.5, 100.2, 96.5, 106.5, 99.0, 94.2, 99.1, 98.6, 99.8, 91.9, 97.0, 95.5, 102.1, 99.2, 95.0, 93.3, 97.3, 104.8, 107.5, 96.3, 99.4, 101.1, 101.5, 105.0, 103.4, 98.6, 99.4, 103.7, 100.2, 94.9, 99.9, 105.9, 91.8, 97.8, 93.6, 90.7, 93.1, 96.3, 97.7, 99.0, 90.9, 93.0, 98.5, 96.6, 94.2, 93.6, 87.0, 103.1, 104.1, 99.7, 97.2, 97.9, 97.3, 97.5, 98.4, 97.8, 98.8, 103.7, 95.0, 95.8, 98.1, 89.6, 100.0, 96.9, 96.5, 93.2, 97.2, 94.7, 93.2, 98.9, 94.9, 96.5, 102.9, 98.0, 93.2, 93.4, 94.1, 105.7, 106.1, 98.0, 97.5, 95.7, 101.1, 101.2, 102.2, 100.2, 95.2, 103.0, 93.4, 106.0, 101.1, 94.1, 101.3, 98.5, 98.6, 96.2, 99.5, 96.7, 93.7, 98.2, 101.0, 95.5, 102.2, 100.7, 96.9, 101.0, 96.5, 106.2, 106.7, 106.9, 104.4, 95.0, 107.9, 104.3, 105.2, 100.5, 103.0, 105.4, 107.7, 96.1, 104.8, 99.7, 104.0, 101.4, 98.0, 92.0, 91.9, 103.1, 100.8, 97.8, 97.3, 98.5, 102.5, 98.5, 94.7, 94.2, 95.7, 102.8, 104.0, 95.1, 101.5, 97.8, 110.0, 106.7, 102.4, 101.3, 98.5, 103.9, 103.2, 98.3, 105.2, 99.4, 104.3, 102.7, 100.0, 102.8, 105.7, 103.4, 102.2, 102.0, 101.6, 104.1, 102.1, 99.0, 98.4, 98.6, 97.4, 114.9, 103.5, 110.2, 104.5, 105.1, 102.3, 99.1, 106.5, 97.7, 106.6, 101.9, 102.7, 102.4, 100.9, 97.3, 102.7, 105.7, 108.0, 110.3, 106.9, 109.2, 103.2, 103.6, 105.1, 102.9, 103.2, 101.3, 104.9, 104.3, 101.1, 102.4, 105.8, 115.9, 105.3, 115.3, 108.7, 100.7, 106.6, 100.5, 107.9, 111.7, 104.3, 97.9, 102.8, 105.6, 104.6, 107.7], "mode": "markers", "x": [23.5, 19.4, 22.2, 20.8, 21.2, 20.6, 21.6, 22.6, 24.7, 23.7, 20.8, 22.6, 23.7, 18.9, 20.1, 24.9, 22.2, 26.9, 22.1, 23.3, 21.6, 20.7, 23.4, 23.5, 25.6, 22.9, 23.8, 22.6, 18.0, 20.6, 19.9, 18.5 ...

# %%
plot_fga()
# Out:
# <div id="c0b31459-265d-4a75-9399-7f7dd617af11" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c0b31459-265d-4a75-9399-7f7dd617af11", [{"name": "Data", "type": "scatter", "y": [94.4, 92.1, 94.8, 100.1, 99.3, 98.0, 96.6, 101.3, 98.4, 97.2, 103.5, 101.2, 97.0, 94.3, 84.8, 96.5, 96.2, 98.5, 101.4, 99.0, 99.5, 93.9, 100.8, 97.5, 98.9, 99.1, 105.0, 95.5, 92.0, 94.7, 88.9, 88.7, 97.5, 94.6, 92.1, 93.2, 100.7, 97.6, 91.9, 92.6, 95.6, 92.2, 91.0, 87.6, 96.2, 97.1, 100.5, 97.3, 97.2, 96.6, 91.7, 100.6, 101.7, 94.0, 95.4, 97.3, 92.5, 92.5, 96.2, 96.4, 100.5, 91.0, 92.8, 87.2, 91.6, 94.3, 93.9, 91.4, 96.8, 97.5, 94.0, 95.3, 89.5, 96.7, 105.2, 99.3, 96.0, 92.3, 92.2, 89.9, 104.6, 101.3, 96.6, 97.7, 95.7, 95.1, 97.7, 95.4, 96.8, 92.7, 98.5, 91.5, 95.9, 85.6, 91.4, 96.8, 93.9, 99.5, 94.1, 95.0, 90.9, 91.4, 95.8, 103.0, 98.1, 94.7, 93.8, 97.5, 84.2, 101.7, 100.4, 95.2, 95.5, 92.1, 102.4, 93.8, 90.3, 90.3, 92.0, 95.3, 88.0, 91.8, 94.0, 91.4, 90.1, 91.8, 98.0, 92.9, 85.4, 92.8, 89.7, 94.5, 91.5, 105.2, 96.7, 89.8, 97.2, 88.7, 98.2, 102.8, 90.7, 93.3, 97.1, 94.2, 94.8, 101.3, 99.1, 91.4, 99.7, 97.3, 93.3, 94.5, 93.0, 96.5, 97.2, 101.5, 100.5, 99.5, 94.3, 92.7, 98.9, 99.5, 96.8, 92.9, 93.0, 110.4, 103.7, 95.7, 98.7, 98.7, 96.2, 102.5, 95.1, 93.4, 88.4, 93.8, 99.4, 98.0, 101.1, 95.6, 96.8, 97.6, 93.9, 97.8, 97.8, 99.9, 101.7, 94.9, 96.9, 97.2, 100.3, 92.4, 102.6, 91.7, 88.8, 108.4, 97.2, 99.4, 98.9, 98.5, 95.6, 99.1, 92.2, 92.8, 90.1, 99.5, 97.6, 94.9, 97.5, 95.8, 96.0, 96.8, 98.8, 95.6, 99.7, 94.6, 104.3, 94.8, 96.9, 93.7, 101.5, 105.4, 94.1, 96.1, 99.1, 110.2, 103.3, 106.5, 95.6, 101.3, 100.0, 98.5, 97.0, 95.5, 101.6, 100.5, 100.2, 96.6, 95.8, 96.9, 97.5, 96.4, 104.0, 97.3, 97.0, 104.5, 98.8, 98.2, 97.1, 91.4, 106.2, 110.7, 95.4, 95.6, 97.5, 108.6, 110.1, 111.0, 102.5, 93.8, 100.9, 95.4, 96.7, 100.4, 100.7, 100.9, 97.4, 98.1, 99.0, 105.2, 100.3, 102.2, 94.2, 105.1, 99.3, 101.0, 98.1, 98.3, 93.6, 96.1, 104.3, 99.4, 103.6, 97.8, 97.0, 106.9, 109.4, 108.6, 95.1, 100.6, 97.0, 98.4, 101.7, 95.8, 93.9, 99.2, 104.1, 102.1, 97.7, 92.4, 102.1, 97.7, 97.5, 100.8, 94.0, 102.8, 101.7, 96.5, 95.3, 96.2, 106.5, 104.2, 98.1, 101.5, 98.2, 101.7, 110.2, 95.7, 108.8, 100.0, 102.0, 101.4, 102.4, 102.5, 100.2, 96.5, 106.5, 99.0, 94.2, 99.1, 98.6, 99.8, 91.9, 97.0, 95.5, 102.1, 99.2, 95.0, 93.3, 97.3, 104.8, 107.5, 96.3, 99.4, 101.1, 101.5, 105.0, 103.4, 98.6, 99.4, 103.7, 100.2, 94.9, 99.9, 105.9, 91.8, 97.8, 93.6, 90.7, 93.1, 96.3, 97.7, 99.0, 90.9, 93.0, 98.5, 96.6, 94.2, 93.6, 87.0, 103.1, 104.1, 99.7, 97.2, 97.9, 97.3, 97.5, 98.4, 97.8, 98.8, 103.7, 95.0, 95.8, 98.1, 89.6, 100.0, 96.9, 96.5, 93.2, 97.2, 94.7, 93.2, 98.9, 94.9, 96.5, 102.9, 98.0, 93.2, 93.4, 94.1, 105.7, 106.1, 98.0, 97.5, 95.7, 101.1, 101.2, 102.2, 100.2, 95.2, 103.0, 93.4, 106.0, 101.1, 94.1, 101.3, 98.5, 98.6, 96.2, 99.5, 96.7, 93.7, 98.2, 101.0, 95.5, 102.2, 100.7, 96.9, 101.0, 96.5, 106.2, 106.7, 106.9, 104.4, 95.0, 107.9, 104.3, 105.2, 100.5, 103.0, 105.4, 107.7, 96.1, 104.8, 99.7, 104.0, 101.4, 98.0, 92.0, 91.9, 103.1, 100.8, 97.8, 97.3, 98.5, 102.5, 98.5, 94.7, 94.2, 95.7, 102.8, 104.0, 95.1, 101.5, 97.8, 110.0, 106.7, 102.4, 101.3, 98.5, 103.9, 103.2, 98.3, 105.2, 99.4, 104.3, 102.7, 100.0, 102.8, 105.7, 103.4, 102.2, 102.0, 101.6, 104.1, 102.1, 99.0, 98.4, 98.6, 97.4, 114.9, 103.5, 110.2, 104.5, 105.1, 102.3, 99.1, 106.5, 97.7, 106.6, 101.9, 102.7, 102.4, 100.9, 97.3, 102.7, 105.7, 108.0, 110.3, 106.9, 109.2, 103.2, 103.6, 105.1, 102.9, 103.2, 101.3, 104.9, 104.3, 101.1, 102.4, 105.8, 115.9, 105.3, 115.3, 108.7, 100.7, 106.6, 100.5, 107.9, 111.7, 104.3, 97.9, 102.8, 105.6, 104.6, 107.7], "mode": "markers", "x": [5260.0, 5437.0, 6133.0, 6144.0, 5620.0, 5507.0, 5791.0, 5153.0, 5532.0, 5711.0, 5412.0, 5758.0, 5815.0, 5993.0, 5148.0, 5526.0, 5511.0, 6194.0, 5721.0, 5514.0, 5039.0, 5543.0, 5789.0, 5302.0 ...
