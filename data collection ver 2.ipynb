# %%
import pandas as pd
import requests
import time
import re
import numpy as np
from bs4 import BeautifulSoup
from sklearn.linear_model import LinearRegression

# %%
data = pd.DataFrame(columns= ['Name', 'Year','Wins','Champion','MVP','Scoring Leader', 
                              'Rebound Leader', 'Assist Leader', 'WS Leader','DPOY',
                              'MIP', '6MOY', 'Coach of Year'#'All-Stars', 'All-NBA',
                              #'All-Defensive', FG%', '3P%', 
                              #'2P%', 'FT%', 'PPG', 'TOV', 'AST', 'STL', 'BLK' 
                              #'SEED', 'GOAT Factor', 'Coach', 'Overall Team Score' 
                             ])
data
# Out:
# Empty DataFrame
# Columns: [Name, Year, Wins, Champion, MVP, Scoring Leader, Rebound Leader, Assist Leader, WS Leader, DPOY, MIP, 6MOY, Coach of Year]
# Index: []

# %%
def check_roster(team_soup, season_awards):
    awards = [0,0,0,0,0,0,0,0,0]
    players = team_soup.find_all('td', {'class':'left', 'data-stat':'player'})
    roster = [player.text for player in players]
    coach = roster.append(team_soup.find(text=re.compile('Coach:')).parent.parent.find('a').text)

 
    for i in range(9):
        if season_awards[i] in roster:
            awards[i] = 1
    
    return awards

# %%
def get_team_row(season_awards, name, team_url, year, wins):
    row = []
    row.append(name.replace('*',''))
    row.append(year)
    row.append(wins)
    
    roster = []
    
    url = 'http://www.basketball-reference.com' + team_url
    req = requests.get(url)
    time.sleep(0.1)
    team_soup = BeautifulSoup(req.text, 'html.parser')
    try:
        row.append(team_soup.find('br').text[:4] == 'Won ')
    except:
        row.append(False)
    row += check_roster(team_soup, season_awards)
    
    return row

# %%
leaders = ['Most Valuable Player', 'PPG Leader', 'RPG Leader',
           'APG Leader', 'WS Leader']

awards = ['Defensive Player of the Year', 'Most Improved Player', 
          'Sixth Man of the Year', 'Coach of the Year']
winners = []

def get_award_winners(season, year):
    for leader in leaders:
        winners.append(season.body.find(text=leader).parent.parent.find('a').text)

    #Using a different site that's more convenient to scrape other awards.
    year_string = '%s' % str(year)
    next_year = '%s' % str(year+1)
    year = '%s-%s' % (year_string, next_year[2:4])
    for award in awards:
        url = 'http://www.nba.com/history/%s-award/' %(award.lower().replace(' ', '-'))
        req = requests.get(url)
        soup = BeautifulSoup(req.text, 'html.parser')

        table = soup.find('table')    
        try:
            winners.append(table.find(text=re.compile(year)).parent.parent.find_all('td')[1].text.strip())
        except:
            winners.append('')
    
    return winners

# %%
# Append all_stars rosters to list
def get_allstar_players(year):
    year_string = '%s' % str(year)
    url = "http://www.basketball-reference.com/allstar/NBA_%s.html/" %year_string
    req = requests.get(url)
    allstar = BeautifulSoup(req.text, 'html.parser')
    count1 = 0
    count2 = 0
    
    for row in allstar.find("div", {"id" : "all_East"}).find_all("th", {"class" : "left", "scope" : "row", "csk" : True}):
        all_stars_East.append(row.find("a").text)   
        count1 += 1
        
    if count1 != 14:
        for i in range(count1, 14):
            all_stars_East.append("")
            count1 += 1
        
    for row in allstar.find("div", {"id" : "all_West"}).find_all("th", {"class" : "left", "scope" : "row", "csk" : True}):
        all_stars_West.append(row.find("a").text)
        count2 += 1
    
    #print(all_stars_East), print(count1), print(all_stars_West), print(count2)
    if count2 != 14:
        for i in range(count2, 14):
            all_stars_West.append("")
            count2 += 1

# %%
years = np.arange(1965, 2017)
index_to_be_delete = 1999 - 1965
years = np.delete(years, index_to_be_delete)
reversed_year = years[::-1]

# %%
num_players = ["Player 1", "Player 2", "Player 3", "Player 4", "Player 5", "Player 6", "Player 7", "Player 8", "Player 9", 
              "Player 10", "Player 11", "Player 12" , "Player 13", "Player 14"]
east = pd.DataFrame(columns=num_players, index = reversed_year).fillna("")
west = pd.DataFrame(columns=num_players, index = reversed_year).fillna("")
row = 0

for i in reversed_year:
    all_stars_East = []
    all_stars_West = []
    
    #print(i)
    get_allstar_players(i)
    time.sleep(0.2)

    east.loc[i, :] = all_stars_East
    west.loc[i, :] = all_stars_West

    row += 1

# %%
num_defends = ["Player 1", "Player 2", "Player 3", "Player 4", "Player 5"]
years_array = []

for year in range(2015,1967,-1):
    year_string = '%s' % str(year)
    next_year = '%s' % str(year+1)
    year = '%s-%s' % (year_string, next_year[2:4])
    years_array.append(year)
    
df_alldefend = pd.DataFrame(columns = num_defends, index = years_array).fillna("")

# %%
## Because we need only 1 request to get the whole defensive page, each five players from list is from the First team of a season.

def get_defensive():
    url = "http://www.nba.com/history/all-defensive-teams/"
    req = requests.get(url)
    defensive = BeautifulSoup(req.text, 'html.parser')
    all_defend = []
        
    ## Get First Team Rosters Only here
    for i in defensive.find_all("td" , {"class" : "cnnIEColTxtL", "style" : "text-align: center"}):
        if i.text == "First Team":
            continue
        else:
            all_defend.append(i.text)
            
    return all_defend

list_alldefend = get_defensive()

# %%
j = 0

for i in years_array:
    df_alldefend.loc[i, :] = list_alldefend[j: (j+5)]
    j += 5

# %%
df_alldefend
# Out:
#                                            Player 1  \
# 2015-16                               Kawhi Leonard
# 2014-15                               Kawhi Leonard
# 2013-14                                 Joakim Noah
# 2012-13                                LeBron James
# 2011-12                                  Chris Paul
# 2010-11                                 Serge Ibaka
# 2009-10                                 Rajon Rondo
# 2008-09                                 Rajon Rondo
# 2007-08                                  Chris Paul
# 2006-07                               Kevin Garnett
# 2005-06                                   Raja Bell
# 2004-05           Kobe Bryant (tie)Jason Kidd (tie)
# 2003-04                                Larry Hughes
# 2002-03                                 Kobe Bryant
# 2001-02                                  Tim Duncan
# 2000-01                                  Tim Duncan
# 1999-00                                  Tim Duncan
# 1998-99                                  Tim Duncan
# 1997-98       Karl Malone (tie)Scottie Pippen (tie)
# 1996-97                              Scottie Pippen
# 1995-96                              Scottie Pippen
# 1994-95                              Scottie Pippen
# 1993-94                              Scottie Pippen
# 1992-93                              Scottie Pippen
# 1991-92                              Scottie Pippen
# 1990-91                              Scottie Pippen
# 1989-90                               Buck Williams
# 1988-89                               Buck Williams
# 1987-88                                 Larry Nance
# 1986-87                             Hakeem Olajuwon
# 1985-86                             Hakeem Olajuwon
# 1984-85                                Paul Pressey
# 1983-84                                Paul Pressey
# 1982-83                                Tree Rollins
# 1981-82    Maurice Cheeks (tie)Dennis Johnson (tie)
# 1980-81                              Michael Cooper
# 1979-80                      Michael Ray Richardson
# 1978-79  Michael Ray Richardson (tie)Don Buse (tie)
# 1977-78                                    Don Buse
# 1976-77                                    Don Buse
# 1975-76                                    Don Buse
# 1974-75                                 Slick Watts
# 1973-74                                 Jerry Sloan
# 1972-73                           Jerry Sloan (tie)
# 1971-72                            Dave DeBusschere
# 1970-71                            Dave DeBusschere
# 1969-70                            Dave DeBusschere
# 1968-69                            Dave DeBusschere
#
#                                     Player 2          Player 3  \
# 2015-16                       Draymond Green    DeAndre Jordan
# 2014-15                       Draymond Green        Tony Allen
# 2013-14                          Paul George        Chris Paul
# 2012-13                          Serge Ibaka    Tyson Chandler
# 2011-12                           Chris Paul        Tony Allen
# 2010-11                          Kobe Bryant     Kevin Garnett
# 2009-10                          Kobe Bryant    Gerald Wallace
# 2008-09                          Kobe Bryant     Kevin Garnett
# 2007-08                          Kobe Bryant       Bruce Bowen
# 2006-07                          Kobe Bryant       Bruce Bowen
# 2005-06                           Ron Artest       Bruce Bowen
# 2004-05                           Tim Duncan       Bruce Bowen
# 2003-04                           Ron Artest       Bruce Bowen
# 2002-03                        Doug Christie       Kobe Bryant
# 2001-02                           Jason Kidd       Gary Payton
# 2000-01                           Jason Kidd       Gary Payton
# 1999-00                          Kobe Bryant       Gary Payton
# 1998-99                           Tim Duncan       Gary Payton
# 1997-98                       Michael Jordan       Karl Malone
# 1996-97                       Michael Jordan       Karl Malone
# 1995-96                       Michael Jordan     Dennis Rodman
# 1994-95                      Mookie Blaylock     Dennis Rodman
# 1993-94                      Mookie Blaylock    Charles Oakley
# 1992-93                           Joe Dumars    Michael Jordan
# 1991-92                           Joe Dumars    Michael Jordan
# 1990-91                      Alvin Robertson    Michael Jordan
# 1989-90                           Joe Dumars    Michael Jordan
# 1988-89                           Joe Dumars    Michael Jordan
# 1987-88                       Michael Cooper    Michael Jordan
# 1986-87                       Michael Cooper    Dennis Johnson
# 1985-86                       Maurice Cheeks        Mark Eaton
# 1984-85                       Maurice Cheeks        Mark Eaton
# 1983-84                       Maurice Cheeks       Bobby Jones
# 1982-83                         Moses Malone       Bobby Jones
# 1981-82                       Dennis Johnson       Bobby Jones
# 1980-81                       Dennis Johnson       Bobby Jones
# 1979-80                       Dennis Johnson       Bobby Jones
# 1978-79                       Dennis Johnson       Bobby Jones
# 1977-78                       Lionel Hollins       Bobby Jones
# 1976-77                         E.C. Coleman       Bobby Jones
# 1975-76                          Dave Cowens     John Havlicek
# 1974-75                  Kareem Abdul-Jabbar     John Havlicek
# 1973-74                  Kareem Abdul-Jabbar     John Havlicek
# 1972-73                   Walt Frazier (tie)  Wilt Chamberlain
# 1971-72                         Walt Frazier  Wilt Chamberlain
# 1970-71  Walt Frazier (tie)Jerry Sloan (tie)       Gus Johnson
# 1969-70                         Walt Frazier       Gus Johnson
# 1968-69                         Walt Frazier       Gus Johnson
#
#                     Player 4          Player 5
# 2015-16        Avery Bradley        Chris Paul
# 2014-15       DeAndre Jordan        Chris Paul
# 2013-14          Serge Ibaka    Andre Iguodala
# 2012-13          Joakim Noah        Tony Allen
# 2011-12        Dwight Howard      LeBron James
# 2010-11        Dwight Howard      LeBron James
# 2009-10        Dwight Howard      LeBron James
# 2008-09        Dwight Howard      LeBron James
# 2007-08         Marcus Camby        Tim Duncan
# 2006-07         Marcus Camby        Tim Duncan
# 2005-06     Andrei Kirilenko       Ben Wallace
# 2004-05        Kevin Garnett       Ben Wallace
# 2003-04        Kevin Garnett       Ben Wallace
# 2002-03        Kevin Garnett       Ben Wallace
# 2001-02        Kevin Garnett       Ben Wallace
# 2000-01        Kevin Garnett   Dikembe Mutombo
# 1999-00        Kevin Garnett   Alonzo Mourning
# 1998-99      Alonzo Mourning        Jason Kidd
# 1997-98      Dikembe Mutombo       Gary Payton
# 1996-97      Dikembe Mutombo       Gary Payton
# 1995-96       David Robinson       Gary Payton
# 1994-95       David Robinson       Gary Payton
# 1993-94      Hakeem Olajuwon       Gary Payton
# 1992-93      Hakeem Olajuwon     Dennis Rodman
# 1991-92       David Robinson     Dennis Rodman
# 1990-91       David Robinson     Dennis Rodman
# 1989-90      Hakeem Olajuwon     Dennis Rodman
# 1988-89           Mark Eaton     Dennis Rodman
# 1987-88        Rodney McCray      Kevin McHale
# 1986-87      Alvin Robertson      Kevin McHale
# 1985-86         Kevin McHale   Sidney Moncrief
# 1984-85       Michael Cooper   Sidney Moncrief
# 1983-84       Michael Cooper   Sidney Moncrief
# 1982-83       Dan Roundfield   Sidney Moncrief
# 1981-82       Dan Roundfield    Caldwell Jones
# 1980-81  Kareem Abdul-Jabbar    Caldwell Jones
# 1979-80  Kareem Abdul-Jabbar    Dan Roundfield
# 1978-79  Kareem Abdul-Jabbar     Bob Dandridge
# 1977-78          Bill Walton     Maurice Lucas
# 1976-77          Bill Walton     Norm Van Lier
# 1975-76           Paul Silas     Norm Van Lier
# 1974-75           Paul Silas      Walt Frazier
# 1973-74        Norm Van Lier  Dave DeBusschere
# 1972-73        John Havlicek        Jerry West
# 1971-72        John Havlicek        Jerry West
# 1970-71        Nate Thurmond        Jerry West
# 1969-70          Willis Reed        Jerry West
# 1968-69          Willis Reed        Jerry West

# %%
list_alldefend[0:5]
# Out:
# ['Kawhi Leonard',
#  'Draymond Green',
#  'DeAndre Jordan',
#  'Avery Bradley',
#  'Chris Paul']

# %%
row_num = 0
for i in range(1965, 1966):
    url = ('http://www.basketball-reference.com/leagues/NBA_%s.html' % str(i))
    time.sleep(0.1)
    req = requests.get(url)
    season = BeautifulSoup(req.text, 'html.parser')
    teams = season.find_all('th', {'class': 'left', 'data-stat':'team_name'})
   
    season_awards = get_award_winners(season, i-1)
    
    as_rosters = get_allstar_players(season, i)
    
    for team in teams:
        if(team.text == 'Team' or 'Conference' in team.text):
            continue
        wins = int(team.parent.find('td', {'data-stat':'wins'}).text)
     
        team_name = repr(team.text).replace('\\x','*').split('*')[0].lstrip("'")
        for a in team.find_all('a',href=True):
            new_row = get_team_row(season_awards,team_name,a['href'], i, wins)
  
            data.loc[row_num] = new_row
            row_num += 1
